# %%
import lhapdf
import pyhepmc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pdf_name = "NNPDF23_lo_as_0130_qed"
pdf_set = lhapdf.getPDFSet(pdf_name)
pdf_size = pdf_set.size-1

# %%
pdf_set.uncertainty
# Out:
# <bound method PDFSet.uncertainty of PDFSet<NNPDF23_lo_as_0130_qed, 100 replicas vars: 36 keys, 31 local>>

# %%
inputFile = "/Users/ramos/mg5amcnlo/nuDIS_charged/Events/run_02/tag_1_pythia8_events.hepmc.gz"

# %%
with pyhepmc.open(inputFile, format="hepmc2") as file:
    events = list(file)
n_events = len(events)

# %%
n_events
# Out:
# 9995

# %%
particles_dict = {}

for i, event in enumerate(events):
    # take only final state particles
    for p in event.particles:
        if p.status != 1: 
            continue
        if p.pid not in particles_dict:
            particles_dict[p.pid] = {}

# %%
proton_id = 2212
piplus_id = 211
piminus_id = -211

for i, event in enumerate(events):
    if i > 10:
        break

    print("\n---------\nEvent %i\n----------\n"%(i))
    for p in event.particles:
        if p.status != 1:  # not "final state"
            continue
    
        if p.pid == proton_id:
            print("Proton")
            if p.production_vertex:
                print("produced at", p.production_vertex.position)
                for parent in p.production_vertex.particles_in:
                    print("parents:",parent.pid, parent.status,"\n")
        if p.pid == piplus_id:
            print("Pion plus")
            if p.production_vertex:
                print("produced at", p.production_vertex.position)
                for parent in p.production_vertex.particles_in:
                    print("(parent id, status):",parent.pid, parent.status,"\n")
# Out:
# ---------
# Event 0
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2203 63
#
# (parent id, status): 2 62
#
# (parent id, status): 21 62
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 223 2
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2224 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2224 2
#
# Pion plus
# produced at FourVector(-7.44e-08, 1.28e-07, 1.77e-07, 3.61e-07)
# (parent id, status): 221 2
#
#
# ---------
# Event 1
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2 71
#
# (parent id, status): 2203 71
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2 71
#
# (parent id, status): 2203 71
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
# Pion plus
# produced at FourVector(11.5, -0.487, 158, 158)
# (parent id, status): 310 2
#
#
# ---------
# Event 2
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2203 63
#
# (parent id, status): 2 62
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 331 2
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2114 2
#
# Pion plus
# produced at FourVector(7.38e-08, -1.02e-07, 9.67e-07, 9.87e-07)
# (parent id, status): 221 2
#
#
# ---------
# Event 3
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2212 4
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2 71
#
# parents: 21 71
#
# parents: 2101 71
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
# Pion plus
# produced at FourVector(-22.8, -3.96, 3.05e+03, 3.05e+03)
# (parent id, status): 310 2
#
#
# ---------
# Event 4
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2203 63
#
# (parent id, status): 2 62
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2203 63
#
# (parent id, status): 2 62
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2224 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2224 2
#
#
# ---------
# Event 5
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 223 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 113 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 223 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 223 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 331 2
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2224 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2224 2
#
#
# ---------
# Event 6
# ----------
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2101 63
#
# parents: 4 62
#
# Pion plus
# produced at FourVector(-5.7e-11, -3.79e-11, 8.7e-09, 8.7e-09)
# (parent id, status): 413 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
#
# ---------
# Event 7
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2203 63
#
# (parent id, status): 2 62
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2203 63
#
# (parent id, status): 2 62
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 113 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
#
# ---------
# Event 8
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 2203 71
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 113 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 223 2
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2214 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
#
# ---------
# Event 9
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 2203 71
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 2203 71
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 21 71
#
# (parent id, status): 2203 71
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 113 2
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 213 2
#
# Proton
# produced at FourVector(-45.5, 59.9, 2.09e+03, 2.09e+03)
# parents: 3122 2
#
#
# ---------
# Event 10
# ----------
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2103 63
#
# (parent id, status): 4 62
#
# (parent id, status): 21 62
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 2103 63
#
# (parent id, status): 4 62
#
# (parent id, status): 21 62
#
# Proton
# produced at FourVector(0, 0, 0, 0)
# parents: 2103 63
#
# parents: 4 62
#
# parents: 21 62
#
# Pion plus
# produced at FourVector(0, 0, 0, 0)
# (parent id, status): 223 2
#
# Pion plus
# produced at FourVector(0.00174, -0.0198, 3.86, 3.86)
# (parent id, status): 213 2
#
# Pion plus
# produced at FourVector(2.41, -7.95, 885, 885)
# (parent id, status): 310 2

# %%
p.production_vertex.position
# Out:
# FourVector(1.1e-06, 3.47e-05, 0.00111, 0.00111)
